# %% [markdown]
# Question 1

# %%
import numpy as np
a= np.random.rand(64)
a.resize((4,4,4))
a*100
a_mean =np.mean(a)
a_std =np.std(a)
a_mean
a_std
zscore=(a-a_mean)/a_std
# Out:
# array([[[ 0.53188977, -1.19201299,  1.80737461,  1.22189062],
#         [-0.46359353,  0.48983797,  1.61871886,  0.80181465],
#         [-0.80874124,  1.26975403, -1.43322598,  0.12069742],
#         [ 0.84911563, -1.13136971, -0.62729063,  1.2782001 ]],
#
#        [[ 0.17685078, -0.7625925 , -0.91981733, -1.28203091],
#         [-1.61354112,  0.00306533, -1.47165491, -1.16083949],
#         [ 1.22476298,  1.61506397,  0.94690561, -0.84374502],
#         [-1.28233288,  1.07605929,  0.90803232, -0.33245225]],
#
#        [[-1.48823139, -1.19041575, -0.06344555,  1.26581169],
#         [ 0.21514782,  1.62542486, -0.01156273, -0.33194215],
#         [-0.97046777, -0.51490655, -0.72959299,  0.82975892],
#         [-0.12594311, -1.66017428, -0.11317852, -1.49116121]],
#
#        [[ 0.64502928, -0.09546985, -0.5672859 ,  1.08294283],
#         [ 0.75166165,  0.1865522 ,  0.80437475,  0.73071321],
#         [ 1.33664495,  0.25248328, -1.08896178, -0.24539808],
# ...

# %% [markdown]
# Question 2

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
filtered_df = df[df['petal length (cm)'] > 3.0]
filtered_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [99 rows x 4 columns]

# %% [markdown]
# Question 3

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Line Graph")
plt.show()

# %% [markdown]
# Question 4

# %%
import pandas as pd
import numpy as np
n=np.nan
data = {"A": [1,2,3,4,5,6,4,7,7,8],"B": [4,7,6,8,3,5,7,8,9,5],"C": [6,8,4,5,7,3,4,6,7,4]}
df = pd.DataFrame(data)

df['A']=df['A'].replace(2,n)
df['B']=df['B'].replace(6,n)
df['C']=df['C'].replace(4,n)

df.head(10)

df['A']=df['A'].replace(n,df['A'].mean())
df['B']=df['B'].replace(n,df['B'].mean())
df['C']=df['C'].replace(n,df['C'].mean())
df.head(10)
# Out:
#      A         B    C
# 0  1.0  4.000000  6.0
# 1  5.0  7.000000  8.0
# 2  3.0  6.222222  6.0
# 3  4.0  8.000000  5.0
# 4  5.0  3.000000  7.0
# 5  6.0  5.000000  3.0
# 6  4.0  7.000000  6.0
# 7  7.0  8.000000  6.0
# 8  7.0  9.000000  7.0
# 9  8.0  5.000000  6.0

# %% [markdown]
# Question 5

# %%
import numpy as np
a= np.random.rand(16)
a.resize((4,4))
a=a*100
b= np.random.rand(16)
b.resize((4,4))
b=b*100
dot_product = np.dot(a,b)
determinant = np.linalg.det(dot_product)
determinant
# Out:
# -22245327258046.266

# %% [markdown]
# Question 6

# %%
import pandas as pd
data = {'NAME': ['A','B','A','C','B'],'DATA': [ 8,3,5,7,5]}
df = pd.DataFrame(data)
grouped_sums = df.groupby('NAME')['DATA'].sum()
grouped_sums
# Out:
# NAME
# A    13
# B     8
# C     7
# Name: DATA, dtype: int64

# %% [markdown]
# Question 7

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)

plt.hist(data, bins=30)
plt.grid(True)
plt.grid(which='major', axis='both', linestyle='--', color='gray', alpha=0.7)
plt.show()

# %% [markdown]
# Question 8

# %%
import numpy as np
a=np.array([[1,2,3,7],[4,7,5,6],[6,8,4,9],[7,2,4,6]])
new_a=a[2:3,1:3]
new_a
# Out:
# array([[8, 4]])

# %% [markdown]
# Question 9

# %%
  import pandas as pd
  a=pd.DataFrame({'A':[3,5,6,7,8],'B':[5,6,7,3,5],'C':[5,4,6,4,6]})
  b=pd.DataFrame({'A':[6,8,9,9,8],'B':[5,6,7,3,5],'C':[4,4,6,6,4]})
  merging=pd.merge(a,b, on='B')
  merging
# Out:
#    A_x  B  C_x  A_y  C_y
# 0    3  5    5    6    4
# 1    3  5    5    8    4
# 2    5  6    4    8    4
# 3    6  7    6    9    6
# 4    7  3    4    9    6
# 5    8  5    6    6    4
# 6    8  5    6    8    4

# %% [markdown]
# Question 10

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)
z=np.random.rand(50)
plt.scatter(x, y, c=z, cmap='viridis', s=15, edgecolors='black', alpha=0.7)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title(" Scatter Plot")
plt.show()
