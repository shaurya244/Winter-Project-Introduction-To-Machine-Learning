# %%
# Q1
import numpy as np

arr3d = np.random.randint(1, 101, (4, 4, 4))

# Calculate the mean and standard deviation of the array
mean = np.mean(arr3d)
std = np.std(arr3d)

# Perform z-score normalization
z_score_normalized_array = (arr3d - mean) / std

arr3d, z_score_normalized_array
# Out:
# (array([[[99, 39, 77, 39],
#          [ 4, 34, 37, 28],
#          [69, 14, 86, 74],
#          [96, 68, 15, 11]],
#
#         [[14, 62, 10, 21],
#          [78, 67, 50, 30],
#          [49, 22, 66, 68],
#          [ 9, 73, 45, 25]],
#
#         [[40, 91, 50, 53],
#          [35, 19, 41,  5],
#          [84, 26,  3, 27],
#          [30, 86, 87, 72]],
#
#         [[77, 32, 84, 87],
#          [46, 73, 73, 91],
#          [49, 21,  5,  1],
#          [ 9, 60, 39, 56]]]),
#  array([[[ 1.83141902, -0.29646269,  1.05119573, -0.29646269],
#          [-1.53772702, -0.47378616, -0.36739208, -0.68657433],
#          [ 0.76747817, -1.18308006,  1.37037799,  0.94480164],
#          [ 1.72502494,  0.73201347, -1.14761537, -1.28947415]],
#
#         [[-1.18308006,  0.5192253 , -1.32493885, -0.9348272 ],
#          [ 1.08666042,  0.69654878,  0.09364896, -0.61564494],
#          [ 0.05818427, -0.8993625 ,  0.66108408,  0.73201347],
#          [-1.36040354,  0.90933695, -0.08367452, -0.79296842]],
# ...

# %%
#Q2
import pandas as pd

# Load the Iris dataset from a built-in source
from sklearn.datasets import load_iris

# Load the dataset into a DataFrame
iris_data = load_iris()
iris_df = pd.DataFrame(data=iris_data.data, columns=iris_data.feature_names)

# Add the target column for species
iris_df['species'] = iris_data.target

# Filter rows where petal length (column index 2) is greater than 3.0
filtered_data = iris_df[iris_df.iloc[:, 2] > 3.0]

filtered_data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species
# 50         1
# ...

# %%
#Q3
import numpy as np
import matplotlib.pyplot as plt

# Create a sample numerical dataset
x = np.linspace(0, 10, 100)  # 100 points between 0 and 10
y = np.sin(x)  # Sine function 

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Sine Wave', color='blue', linestyle='-', linewidth=2)

# Add a title, axis labels, and a legend
plt.title("Trend of a Numerical Dataset: Sine Wave", fontsize=16)
plt.xlabel("X-axis: Input Values", fontsize=12)
plt.ylabel("Y-axis: Sine Values", fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
#Q4
import pandas as pd
import numpy as np

# Create a DataFrame with random values and introduce some NaN values
np.random.seed(42)  
df = pd.DataFrame({
    'Column_A': np.random.randint(1, 100, 10),
    'Column_B': np.random.randint(1, 100, 10),
    'Column_C': np.random.randint(1, 100, 10)
})

# Introduce NaN values randomly
df.iloc[2, 1] = np.nan
df.iloc[5, 2] = np.nan

# (i) Replace NaN values with the mean of the respective column
df_filled = df.copy()
df_filled.fillna(df.mean(), inplace=True)

# (ii) Sort the DataFrame based on two columns: 'Column_A' and 'Column_B'
df_sorted = df_filled.sort_values(by=['Column_A', 'Column_B'])

df, df_filled, df_sorted
# Out:
# (   Column_A  Column_B  Column_C
#  0        52      88.0      64.0
#  1        93      24.0      60.0
#  2        15       NaN      21.0
#  3        72      22.0      33.0
#  4        61      53.0      76.0
#  5        21       2.0       NaN
#  6        83      88.0      22.0
#  7        87      30.0      89.0
#  8        75      38.0      49.0
#  9        75       2.0      91.0,
#     Column_A   Column_B   Column_C
#  0        52  88.000000  64.000000
#  1        93  24.000000  60.000000
#  2        15  38.555556  21.000000
#  3        72  22.000000  33.000000
#  4        61  53.000000  76.000000
#  5        21   2.000000  56.111111
#  6        83  88.000000  22.000000
#  7        87  30.000000  89.000000
#  8        75  38.000000  49.000000
#  9        75   2.000000  91.000000,
#     Column_A   Column_B   Column_C
#  2        15  38.555556  21.000000
#  5        21   2.000000  56.111111
#  0        52  88.000000  64.000000
#  4        61  53.000000  76.000000
# ...

# %%
#Q5
# Create two random matrices of compatible dimensions for dot product
matrix_a = np.random.randint(1, 10, (3, 3))  # 3x3 matrix
matrix_b = np.random.randint(1, 10, (3, 3))  # 3x3 matrix

# Calculate the dot product
dot_product = np.dot(matrix_a, matrix_b)

# Calculate the determinant of the resulting matrix
determinant = np.linalg.det(dot_product)

matrix_a, matrix_b, dot_product, determinant
# Out:
# (array([[3, 7, 4],
#         [9, 3, 5],
#         [3, 7, 5]]),
#  array([[9, 7, 2],
#         [4, 9, 2],
#         [9, 5, 2]]),
#  array([[ 91, 104,  28],
#         [138, 115,  34],
#         [100, 109,  30]]),
#  -1079.9999999999918)

# %%
#Q6
import pandas as pd

# Create a sample DataFrame
data = {
    'Category': ['A', 'B', 'A', 'C', 'B', 'C', 'A'],
    'Values': [10, 20, 30, 40, 50, 60, 70]
}
df = pd.DataFrame(data)

# Group by the 'Category' column and calculate the sum of 'Values' for each group
grouped_sum = df.groupby('Category')['Values'].sum()

print(grouped_sum)
# Out:
# Category
# A    110
# B     70
# C    100
# Name: Values, dtype: int64

# %%
#Q7
import matplotlib.pyplot as plt
import numpy as np

# Create a numerical dataset
data = np.random.normal(loc=50, scale=10, size=1000)  # Normally distributed data

# Plot a histogram
plt.figure(figsize=(10, 6))
plt.hist(data, bins=20, color='blue', edgecolor='black', alpha=0.7)

# Add title, labels, and grid lines
plt.title("Histogram of Numerical Dataset", fontsize=16)
plt.xlabel("Value", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
#Q8
import numpy as np


array_2d = np.random.randint(1, 20, (5, 5))  # 5x5 matrix with random integers between 1 and 20

# Perform slicing to extract a specific sub-array
# Extract the sub-array consisting of rows 1 to 3 and columns 2 to 4 (0-indexed)
sub_array = array_2d[1:4, 2:5]

array_2d, sub_array
# Out:
# (array([[ 4, 10, 19, 18,  5],
#         [19, 16,  1, 12,  2],
#         [ 8, 18, 16,  5, 13],
#         [19,  3,  8, 12,  2],
#         [11, 12, 18, 13,  5]]),
#  array([[ 1, 12,  2],
#         [16,  5, 13],
#         [ 8, 12,  2]]))

# %%
#Q9
import pandas as pd

# Create the first DataFrame
data1 = {
    'ID': [1, 2, 3, 4],
    'Name': ['lakshansh', 'dyvanshu', 'ajay', 'kunal'],
    'Age': [21, 20, 19, 22]
}
df1 = pd.DataFrame(data1)

# Create the second DataFrame
data2 = {
    'ID': [3, 4, 5, 6],
    'Department': ['CHE', 'CE', 'MSE', 'SDS'],
    'CPI': [8.1, 8.5, 9.1, 8.4]
}
df2 = pd.DataFrame(data2)

# Perform the merge operation based on the 'ID' column
merged_df = pd.merge(df1, df2, on='ID', how='inner')  # Use 'inner' join for common IDs

print(merged_df)
# Out:
#    ID   Name  Age Department  CPI
# 0   3   ajay   19        CHE  8.1
# 1   4  kunal   22         CE  8.5

# %%
#10
import matplotlib.pyplot as plt
import numpy as np

# Create a dataset with two numerical variables
x = np.random.rand(50) * 100  
y = np.random.rand(50) * 200  

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='purple', marker='^', alpha=0.8, label='Data Points')

# Customize the plot
plt.title("Scatter Plot Comparing Two Numerical Variables", fontsize=16)
plt.xlabel("Variable X", fontsize=12)
plt.ylabel("Variable Y", fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a sample dataset
x = np.random.uniform(10, 100, 50)  
y = 2 * x + np.random.normal(0, 10, 50)  # Dependent variable Y with some noise

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='purple', marker='o', alpha=0.7, edgecolor='black')

# Customize the plot
plt.title("Scatter Plot Comparing Two Numerical Variables", fontsize=16)
plt.xlabel("Variable X", fontsize=12)
plt.ylabel("Variable Y", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a sample dataset
x = np.random.uniform(10, 100, 50)  # 50 random numbers for variable X
y = 2 * x + np.random.normal(0, 10, 50)  # Dependent variable Y with some noise

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='purple', marker='o', alpha=0.7, edgecolor='black')

# Customize the plot
plt.title("Scatter Plot Comparing Two Numerical Variables", fontsize=16)
plt.xlabel("Variable X", fontsize=12)
plt.ylabel("Variable Y", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a dataset with two numerical variables
x = np.random.rand(50) * 100  
y = np.random.rand(50) * 200  

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='purple', marker='^', alpha=0.8, label='Data Points')

# Customize the plot
plt.title("Scatter Plot Comparing Two Numerical Variables", fontsize=16)
plt.xlabel("Variable X", fontsize=12)
plt.ylabel("Variable Y", fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
