# %% [markdown]
# # Assignment 1

# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# %% [markdown]
# Q1. Using NumPy, create a 3D array of shape (4, 4, 4) filled with random numbers between 1 and 100. Find the z score normalisation of each element of the array.

# %%
rand = np.random.randint(2, 100, (4, 4, 4))
rand
# Out:
# array([[[72, 82, 19, 64],
#         [70, 36, 61, 77],
#         [32, 50, 79, 54],
#         [27, 27,  3, 37]],
#
#        [[48, 92, 91, 85],
#         [56, 55, 51, 35],
#         [ 8, 17, 21, 75],
#         [91, 46, 61, 85]],
#
#        [[39, 44, 54, 81],
#         [45, 61,  2, 31],
#         [23, 49, 47, 20],
#         [ 6,  4, 70, 67]],
#
#        [[56, 74, 54, 12],
#         [27, 13, 42, 42],
#         [11, 74,  9, 43],
#         [34, 38, 67, 63]]])

# %%
mean = np.mean(rand)
std = np.std(rand)
z_score = (rand-mean)/std
z_score
# Out:
# array([[[ 1.00454940e+00,  1.40662045e+00, -1.12642718e+00,
#           6.82892553e-01],
#         [ 9.24135185e-01, -4.42906394e-01,  5.62271238e-01,
#           1.20558492e+00],
#         [-6.03734815e-01,  1.19993080e-01,  1.28599913e+00,
#           2.80821501e-01],
#         [-8.04770341e-01, -8.04770341e-01, -1.76974087e+00,
#          -4.02699289e-01]],
#
#        [[ 3.95788692e-02,  1.80869150e+00,  1.76848440e+00,
#           1.52724176e+00],
#         [ 3.61235711e-01,  3.21028606e-01,  1.60200185e-01,
#          -4.83113499e-01],
#         [-1.56870534e+00, -1.20684139e+00, -1.04601297e+00,
#           1.12517071e+00],
#         [ 1.76848440e+00, -4.08353413e-02,  5.62271238e-01,
#           1.52724176e+00]],
#
#        [[-3.22285078e-01, -1.21249552e-01,  2.80821501e-01,
#           1.36641334e+00],
#         [-8.10424465e-02,  5.62271238e-01, -1.80994797e+00,
#          -6.43941920e-01],
#         [-9.65598762e-01,  7.97859745e-02, -6.28236020e-04,
#          -1.08622008e+00],
#         [-1.64911955e+00, -1.72953376e+00,  9.24135185e-01,
#           8.03513869e-01]],
#
#        [[ 3.61235711e-01,  1.08496361e+00,  2.80821501e-01,
#          -1.40787692e+00],
#         [-8.04770341e-01, -1.36766981e+00, -2.01663762e-01,
#          -2.01663762e-01],
#         [-1.44808403e+00,  1.08496361e+00, -1.52849824e+00,
#          -1.61456657e-01],
#         [-5.23320604e-01, -3.62492183e-01,  8.03513869e-01,
#           6.42685448e-01]]])

# %% [markdown]
# Q2. Using Pandas, filter the rows in the Iris dataset where the petal length is greater than 3.0, and display the filtered data.

# %%
iris = datasets.load_iris()
iris_df=pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['class']=iris.target
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [150 rows x 5 columns]

# %%
filtered_data = iris_df[iris_df['petal length (cm)'] > 3.0]
filtered_data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      class
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [99 rows x 5 columns]

# %% [markdown]
# Q3. Using Matplotlib, plot a line graph showing the trend of a numerical dataset. Customize the plot with title, axis labels, and a legend.

# %%
import matplotlib as mp
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes = datasets.load_diabetes()
X = diabetes['data']
y = diabetes['target']

# %%
plt.figure(figsize=(35, 5))
plt.plot(y, linewidth = 1, label= 'target')

plt.title('Trend of Numerical Dataset')
plt.xlabel('X-axis (Independent Variable)')
plt.ylabel('Y-axis (Dependent Variable)')
plt.legend()
plt.grid(True, linestyle='--')

plt.show()

# %% [markdown]
# Q4.Create a Pandas DataFrame with random values with at least 3 columns and perform the following operations: (i) Replace NaN values with the mean of the column. (ii) Sort the DataFrame based on any two columns.

# %%
data = {
    "A": np.random.randint(1, 100, 10),
    "B": np.random.choice([np.nan, *np.random.randint(1, 100, 9)], 10),
    "C": np.random.choice([np.nan, *np.random.randint(1, 100, 9)], 10),
}
df = pd.DataFrame(data)
df
# Out:
#     A     B     C
# 0  41  76.0  25.0
# 1  35  36.0  97.0
# 2  33  41.0  46.0
# 3  18  72.0  46.0
# 4   4   NaN  66.0
# 5  60  35.0  66.0
# 6  60  72.0  25.0
# 7  74  36.0  75.0
# 8  82  24.0  25.0
# 9  13  76.0  46.0

# %%
df.fillna(df.mean(), inplace = True)
df
# Out:
#     A     B     C
# 0  41  76.0  25.0
# 1  35  36.0  97.0
# 2  33  41.0  46.0
# 3  18  72.0  46.0
# 4   4  52.0  66.0
# 5  60  35.0  66.0
# 6  60  72.0  25.0
# 7  74  36.0  75.0
# 8  82  24.0  25.0
# 9  13  76.0  46.0

# %%
sorted_df = df.sort_values(by=["A", "B"])
sorted_df
# Out:
#     A     B     C
# 4   4  52.0  66.0
# 9  13  76.0  46.0
# 3  18  72.0  46.0
# 2  33  41.0  46.0
# 1  35  36.0  97.0
# 0  41  76.0  25.0
# 5  60  35.0  66.0
# 6  60  72.0  25.0
# 7  74  36.0  75.0
# 8  82  24.0  25.0

# %% [markdown]
# Q5. Using NumPy, calculate the dot product of two matrices and find the determinant of the resulting matrix.

# %%
a = np.random.randint(1, 10, (3, 3))
b = np.random.randint(1, 10, (3, 3))
c = a@b
print(c)
# Out:
# [[ 84 174  57]
#  [ 78 140  37]
#  [ 29  56  15]]

# %%
np.linalg.det(c)
# Out:
# 3029.999999999994

# %% [markdown]
# Q6. With Pandas, group a DataFrame by a categorical column and calculate the sum of another numerical column for each group.

# %%
data = {
    'Category': np.random.randint(1, 4, 10),
    'Values': np.random.randint(1, 100, 10)
}
df = pd.DataFrame(data)
grouped = df.groupby('Category')
grouped_sum = grouped['Values'].sum()
print(grouped_sum)
# Out:
# Category
# 1    171
# 2     35
# 3    329
# Name: Values, dtype: int32

# %% [markdown]
# Q7. Using Matplotlib, create a histogram to show the distribution of a numerical dataset. Customize the number of bins and add grid lines for better readability.

# %%
diabetes = datasets.load_diabetes()
X = diabetes['data']
y = diabetes['target']
plt.hist(y, bins = 40)
plt.title('Distribution of Numerical Dataset')
plt.xlabel('X-axis (Independent Variable)')
plt.ylabel('Y-axis (Dependent Variable)')
plt.grid(True, linestyle='--', alpha = 0.5)
plt.show()

# %% [markdown]
# Q8. Using NumPy, create a 2D array and perform a slicing operation to extract a specific sub-array.

# %%
arr = np.random.randint(1, 10, (4, 4))
sliced_arr = arr[0:2, 1:4]
print(arr)
print(sliced_arr)
# Out:
# [[5 7 3 9]
#  [5 6 8 7]
#  [1 9 6 8]
#  [4 5 7 7]]
# [[7 3 9]
#  [6 8 7]]

# %% [markdown]
# Q9. Using Pandas, perform a merge operation between two DataFrames based on a common column for dataset of your choice.

# %%
df1 = pd.DataFrame({
    'product_key' : [1, 2, 3, 4],
    'product_name' : ['jam', 'juice', 'chocolate', 'milk'],
    'mrp' : [90, 20, 45, 25]
})
df2 = pd.DataFrame({
    'product_key' : [1, 2, 3, 4],
    'units' : [100, 45, 150, 20],
    'sold' : [20, 20, 95, 15]
})
merged_df = pd.merge(df1, df2, on='product_key', how='inner')
print(merged_df)
# Out:
#    product_key product_name  mrp  units  sold
# 0            1          jam   90    100    20
# 1            2        juice   20     45    20
# 2            3    chocolate   45    150    95
# 3            4         milk   25     20    15

# %% [markdown]
# Q10. Using Matplotlib, create a scatter plot comparing two numerical variables in the dataset of your choice. Customize the plot by changing the color and shape of the data points.

# %%
plt.scatter(iris_df['sepal length (cm)'], iris_df['sepal width (cm)'], c = 'pink', s =30)

plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')

plt.show()
