# %% [markdown]
# # Assignment 1

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
import matplotlib as mp
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Q1. Using NumPy, create a 3D array of shape (4, 4, 4) filled with random numbers between 1 and 100. Find the z score normalisation of each element of the array.

# %%
rand = np.random.randint(2, 100, (4, 4, 4))
print(rand)
mean = np.mean(rand)
std = np.std(rand)
z_score = (rand-mean)/std
print(z_score)
# Out:
# [[[18 86 79 74]
#   [ 2 52 46 78]
#   [ 5 63 66 33]
#   [35 93 96 73]]
#
#  [[40 27 35 55]
#   [ 4 51 13 66]
#   [55  6 95 95]
#   [58 18 48 24]]
#
#  [[80 86 15 67]
#   [76 52 39 65]
#   [99 39 51 99]
#   [83 31 80 92]]
#
#  [[52 64 99 53]
#   [39 98 89 80]
#   [31 52 82  6]
#   [30  5 11 57]]]
# [[[-1.2589996   1.08352552  0.84238323  0.67013873]
#   [-1.81018198 -0.08773704 -0.29443043  0.80793433]
#   [-1.70683528  0.29120085  0.39454754 -0.74226612]
#   [-0.67336832  1.32466781  1.42801451  0.63568983]]
#
#  [[-0.50112382 -0.94895951 -0.67336832  0.01560966]
#   [-1.74128418 -0.12218594 -1.43124409  0.39454754]
#   [ 0.01560966 -1.67238638  1.39356561  1.39356561]
#   [ 0.11895635 -1.2589996  -0.22553263 -1.0523062 ]]
#
#  [[ 0.87683213  1.08352552 -1.36234629  0.42899644]
#   [ 0.73903653 -0.08773704 -0.53557272  0.36009864]
#   [ 1.5313612  -0.53557272 -0.12218594  1.5313612 ]
#   [ 0.98017882 -0.81116391  0.87683213  1.29021891]]
#
#  [[-0.08773704  0.32564975  1.5313612  -0.05328814]
#   [-0.53557272  1.4969123   1.18687221  0.87683213]
#   [-0.81116391 -0.08773704  0.94572992 -1.67238638]
#   [-0.84561281 -1.70683528 -1.50014189  0.08450745]]]

# %% [markdown]
# Q2. Using Pandas, filter the rows in the Iris dataset where the petal length is greater than 3.0, and display the filtered data.

# %%
iris = datasets.load_iris()
iris_df=pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['class']=iris.target

filtered_data = iris_df[iris_df['petal length (cm)'] > 3.0]
print(filtered_data)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      class
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1
# ..     ...
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
#
# [99 rows x 5 columns]

# %% [markdown]
# Q3. Using Matplotlib, plot a line graph showing the trend of a numerical dataset. Customize the plot with title, axis labels, and a legend.

# %%
diabetes = datasets.load_diabetes()
X = diabetes['data']
y = diabetes['target']
plt.figure(figsize=(35, 5))
plt.plot(y, linewidth = 1, label= 'target')

plt.title('Trend of Numerical Dataset')
plt.xlabel('X-axis (Independent Variable)')
plt.ylabel('Y-axis (Dependent Variable)')
plt.legend()
plt.grid(True, linestyle='--')

plt.show()

# %% [markdown]
# Q4.Create a Pandas DataFrame with random values with at least 3 columns and perform the following operations: (i) Replace NaN values with the mean of the column. (ii) Sort the DataFrame based on any two columns.

# %%
data = {
    "A": np.random.randint(1, 100, 10),
    "B": np.random.choice([np.nan, *np.random.randint(1, 100, 9)], 10),
    "C": np.random.choice([np.nan, *np.random.randint(1, 100, 9)], 10),
}
df = pd.DataFrame(data)
print(df)
df.fillna(df.mean(), inplace = True)
print(df)
sorted_df = df.sort_values(by=["A", "B"])
print(sorted_df)
# Out:
#     A     B     C
# 0  17  95.0   5.0
# 1  74  75.0  82.0
# 2  17  95.0   NaN
# 3  84  75.0   5.0
# 4  88  95.0  61.0
# 5  69  75.0  22.0
# 6  34  43.0  51.0
# 7   6  43.0   NaN
# 8  53  77.0  22.0
# 9  66  16.0  61.0
#     A     B       C
# 0  17  95.0   5.000
# 1  74  75.0  82.000
# 2  17  95.0  38.625
# 3  84  75.0   5.000
# 4  88  95.0  61.000
# 5  69  75.0  22.000
# 6  34  43.0  51.000
# 7   6  43.0  38.625
# 8  53  77.0  22.000
# 9  66  16.0  61.000
#     A     B       C
# 7   6  43.0  38.625
# 0  17  95.0   5.000
# 2  17  95.0  38.625
# 6  34  43.0  51.000
# 8  53  77.0  22.000
# 9  66  16.0  61.000
# 5  69  75.0  22.000
# 1  74  75.0  82.000
# 3  84  75.0   5.000
# 4  88  95.0  61.000

# %% [markdown]
# Q5. Using NumPy, calculate the dot product of two matrices and find the determinant of the resulting matrix.

# %%
a = np.random.randint(1, 10, (3, 3))
b = np.random.randint(1, 10, (3, 3))
c = a@b
print(c)
np.linalg.det(c)
# Out:
# [[ 93 147 162]
#  [ 38  71  84]
#  [ 53  68  75]]
# 8505.0

# %% [markdown]
# Q6. With Pandas, group a DataFrame by a categorical column and calculate the sum of another numerical column for each group.

# %%
data = {
    'Category': np.random.randint(1, 4, 10),
    'Values': np.random.randint(1, 100, 10)
}
df = pd.DataFrame(data)
grouped = df.groupby('Category')
grouped_sum = grouped['Values'].sum()
print(grouped_sum)
# Out:
# Category
# 1     39
# 2    163
# 3    318
# Name: Values, dtype: int32

# %% [markdown]
# Q7. Using Matplotlib, create a histogram to show the distribution of a numerical dataset. Customize the number of bins and add grid lines for better readability.

# %%
diabetes = datasets.load_diabetes()
X = diabetes['data']
y = diabetes['target']
plt.hist(y, bins = 40)
plt.title('Distribution of Numerical Dataset')
plt.xlabel('X-axis (Independent Variable)')
plt.ylabel('Y-axis (Dependent Variable)')
plt.grid(True, linestyle='--', alpha = 0.5)
plt.show()

# %% [markdown]
# Q8. Using NumPy, create a 2D array and perform a slicing operation to extract a specific sub-array.

# %%
arr = np.random.randint(1, 10, (4, 4))
sliced_arr = arr[0:2, 1:4]
print(arr)
print('Sliced arr:', sliced_arr)
# Out:
# [[7 6 9 1]
#  [4 9 4 3]
#  [9 2 4 6]
#  [2 8 8 1]]
# Sliced arr: [[6 9 1]
#  [9 4 3]]

# %% [markdown]
# Q9. Using Pandas, perform a merge operation between two DataFrames based on a common column for dataset of your choice.

# %%
df1 = pd.DataFrame({
    'product_key' : [1, 2, 3, 4],
    'product_name' : ['jam', 'juice', 'chocolate', 'milk'],
    'mrp' : [90, 20, 45, 25]
})
df2 = pd.DataFrame({
    'product_key' : [1, 2, 3, 4],
    'units' : [100, 45, 150, 20],
    'sold' : [20, 20, 95, 15]
})
merged_df = pd.merge(df1, df2, on='product_key', how='inner')
print(merged_df)
# Out:
#    product_key product_name  mrp  units  sold
# 0            1          jam   90    100    20
# 1            2        juice   20     45    20
# 2            3    chocolate   45    150    95
# 3            4         milk   25     20    15

# %% [markdown]
# Q10. Using Matplotlib, create a scatter plot comparing two numerical variables in the dataset of your choice. Customize the plot by changing the color and shape of the data points.

# %%
plt.scatter(iris_df['sepal length (cm)'], iris_df['sepal width (cm)'], c = 'pink', s =30)

plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')

plt.show()
